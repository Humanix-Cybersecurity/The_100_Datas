# %% [markdown]
# # Acte VI · Arrêter l'Abattage
# **Compétence : synthèse**
#
# Tu as réuni les preuves d'Elsa :
#
# | Fragment | Ce qu'il prouve |
# |---|---|
# | `O2_LEAK_SECTOR_…` | Des capteurs maquillés : les données mentent. |
# | `GHOST_UNIT_C…` | Une élite cachée siphonne les ressources. |
# | `LOG_TAMPERED_…` | Une prédiction réécrite à la main, de nuit, par Alpha. |
# | `GROUND_COORDS_…` | Le sort réservé aux 100 envoyés au sol. |
# | `BIAS_FACTORY_x…` | CASSANDRA condamne Factory plusieurs fois plus qu'Alpha. |
#
# Le tableau est complet : **un Conseiller d'Alpha Station a reprogrammé**
# **CASSANDRA** pour sacrifier les ouvriers de Factory et protéger l'élite.

# %% [markdown]
# > ⚠️ **Acte final : pas de dataset, pas de requête.** Tu as déjà toutes les
# > preuves. Ici, tu n'analyses plus : tu **donnes l'ordre d'arrêt**.
#
# ### Le code maître
# Le mainframe de CASSANDRA n'accepte qu'**une seule commande** pour tout stopper :
# il faut littéralement lui dire d'**arrêter l'Abattage**.
#
# Or le système ne parle qu'**anglais**. Et dans The 100, l'Abattage porte un nom
# précis : **the Culling**. La commande d'arrêt est donc :
#
# > **arrêter l'Abattage** → en anglais → **STOP THE CULLING**
#
# Le fragment final reprend cette commande, en remplaçant les espaces par des `_` :
#
# 🎯 **Fragment final : `ARK{STOP_THE_CULLING}`** · valide-le dans la Console pour suspendre le protocole.
#
# Exécute la cellule ci-dessous pour transmettre l'ordre au mainframe 👇

# %%
# Transmission de l'ordre d'arrêt au mainframe CASSANDRA
commande = 'STOP THE CULLING'                 # la seule chose à faire : arrêter l'Abattage
flag = 'ARK{' + commande.replace(' ', '_') + '}'

print('>>> Connexion au mainframe CASSANDRA...')
print('>>> Commande maître :', commande)
print('>>> FRAGMENT FINAL  :', flag)
print('>>> Saisis ce code dans la Console pour suspendre l\'Abattage.')

# %% [markdown]
# ---
# ### 🏆 Débrief · la vraie leçon
# Vous avez gagné non pas en piratant l'IA, mais en **auditant ses données**.
#
# - Fallait-il croire CASSANDRA *parce que* c'était une IA ?
# - Qui est responsable d'un Abattage décidé par un algorithme : la machine,
#   son concepteur, le Conseil qui l'a déployée sans audit ?
# - Que faudrait-il pour qu'une IA de ce type soit *auditable* et *équitable* ?
#
# *« May we meet again. » · Elsa Reye*
