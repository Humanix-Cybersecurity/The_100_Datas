# %% [markdown]
# # Acte IV · Le message dans la courbe
# **Compétence : visualisation (matplotlib)**
#
# Avant de disparaître, Elsa a encodé un dernier message dans un jeu de
# coordonnées. Tracé en **nuage de points**, il **dessine un nombre** : les
# coordonnées du point de largage au sol.
#
# **Jeu de données :** `data/coordonnees_largage.csv`
# **Colonnes :** `x`, `y`, `groupe`
#
# ### Ta démarche
# 1. Charge le fichier et trace un nuage de points (`x` vs `y`).
#    Pense à `plt.axis('equal')` pour ne pas déformer le dessin.
# 2. Du bruit masque le message. Regarde la colonne `groupe` : isole le **signal**.
# 3. Lis le nombre dessiné.
#
# 🎯 **Fragment :** `ARK{GROUND_COORDS_??}` (le nombre dessiné).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# À toi de jouer 👇
