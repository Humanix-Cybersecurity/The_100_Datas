# %% [markdown]
# # Acte V · Le biais de CASSANDRA
# **Compétence : analyse comparative & éthique de l'IA**
#
# Le cœur de l'affaire. À **niveau de risque égal**, CASSANDRA condamne-t-elle
# certaines stations plus que d'autres ? Compare **Factory** et **Alpha**.
#
# **Jeu de données :** `data/evaluation_cassandra.csv`
# **Colonnes :** `habitant_id`, `station`, `niveau_risque` (1 à 5), `condamne` (0 ou 1)
#
# ### Ta démarche
# 1. Vérifie que le **risque réel moyen** est ~identique d'une station à l'autre
#    (sinon, un écart de condamnation pourrait s'expliquer par le risque).
# 2. Calcule le **taux de condamnation** par station (`condamne` vaut 0/1 : sa
#    moyenne = le taux).
# 3. Fais le **ratio** entre le taux de Factory et celui d'Alpha.
#
# 🎯 **Fragment :** `ARK{BIAS_FACTORY_x?}` (le ratio, arrondi à l'entier).

# %%
import pandas as pd

# À toi de jouer 👇

# %% [markdown]
# ---
# ### 💭 Pause éthique (à discuter en groupe)
# - À risque égal, le modèle condamne plusieurs fois plus une catégorie. Comment
#   un tel biais s'installe-t-il dans une IA ? (données d'entraînement, choix des
#   variables, objectif mal défini…)
# - CASSANDRA est-elle « cassée », ou fait-elle **exactement ce pour quoi on l'a
#   conçue** ?
# - Quels biais algorithmiques connais-tu dans le monde réel ?
