# %% [markdown]
# # Acte I · La fuite d'oxygène
# **Compétence : nettoyage de données (Pandas)**
#
# Les capteurs O2 de l'Arche renvoient des relevés **sales** : doublons,
# valeurs manquantes, dates illisibles. Une fois tout nettoyé, il reste des
# relevés **physiquement impossibles** (un taux d'O2 réaliste tourne autour de
# 19–21 %). Ils proviennent tous d'**un seul secteur** : la fuite qu'on a maquillée.
#
# **Jeu de données :** `data/capteurs_o2.csv`
# **Colonnes :** `id`, `horodatage`, `secteur`, `taux_o2`, `capteur_id`
#
# ### Ta démarche
# 1. Charge le fichier et inspecte-le (`.info()`, `.describe()`).
# 2. Supprime les doublons.
# 3. Élimine les lignes où `secteur` ou `taux_o2` est vide.
# 4. Répare la colonne `horodatage` (les dates illisibles doivent disparaître).
# 5. Isole les relevés au taux d'O2 **impossible**, puis regarde leur `secteur`.
#
# 🎯 **Fragment :** `ARK{O2_LEAK_SECTOR_?}` (remplace `?` par le n° du secteur).

# %%
import pandas as pd

# À toi de jouer 👇
