# %% [markdown]
# # 🛰️ PROTOCOLE CASSANDRA · Terminal Go-Sci Station
#
# > *« CASSANDRA ment. Les données ont été truquées. Suivez la trace.
# > La preuve est dans les chiffres. »* · Dr. Elsa Reye
#
# Auditeur, l'Abattage tombe à **17h00**. Analyse les données d'Elsa pour
# récupérer **6 fragments** `ARK{...}`, un par notebook.
#
# ## Mode d'emploi
# 1. Ouvre les notebooks **dans l'ordre** (`01_…`, `02_…`, etc.).
# 2. Chaque notebook te donne un **objectif** et les **colonnes** du jeu de données.
#    À toi d'écrire le code : **rien n'est pré-rempli**, c'est l'enquête.
# 3. Trouve le code `ARK{...}` et valide-le dans la **Console** → http://localhost:5005
# 4. Bloqué ? La console délivre **3 indices** par acte (de plus en plus précis,
#    avec un petit malus). Sers-t'en sans culpabiliser, mais cherche d'abord.
#
# Les données sont dans le dossier `data/`. *May we meet again.*

# %% [markdown]
# ### Pour démarrer : charger un fichier
# On lit un CSV avec **pandas**. Exemple générique (à adapter à chaque acte) :

# %%
import pandas as pd

df = pd.read_csv('data/capteurs_o2.csv')   # remplace par le bon fichier
df.head()        # aperçu des premières lignes
# df.info()      # types, valeurs manquantes
# df.describe()  # statistiques
