# %% [markdown]
# # Acte II · L'unité fantôme
# **Compétence : agrégation (`groupby`)**
#
# Une unité d'habitation consomme à elle seule plus de ressources que des
# stations entières, mais elle n'est rattachée à **aucune station connue**.
# Trouve-la en **agrégeant** la consommation par unité.
#
# **Jeu de données :** `data/consommation_unites.csv`
# **Colonnes :** `unite_id`, `station`, `type_ressource`, `quantite`, `horodatage`
#
# ### Ta démarche
# 1. Charge le fichier. Quelles `station` existent ? Une valeur détonne-t-elle ?
# 2. Calcule la **consommation totale par unité** et trie-la du plus grand au plus petit.
# 3. L'unité en tête écrase tout le reste : note son identifiant (forme `C-XXX`).
#
# 🎯 **Fragment :** `ARK{GHOST_UNIT_C???}` (l'identifiant sans le tiret, ex. `C-137` → `C137`).

# %%
import pandas as pd

# À toi de jouer 👇
