# %% [markdown]
# # Acte III · Le registre verrouillé
# **Compétence : SQL (jointure)**
#
# Le Registre Central garde la trace de chaque prédiction de CASSANDRA et de
# chaque action du Conseil. Quelqu'un a **réécrit une prédiction à la main**,
# en pleine nuit. Retrouve le **log** de cette falsification.
#
# 🎯 **Fragment :** `ARK{LOG_TAMPERED_????}` (le n° du log sur 4 chiffres, ex. `0247`).

# %% [markdown]
# ## Le plus simple : Adminer (interface SQL visuelle)
# Ouvre **http://localhost:8080** et connecte-toi :
#
# | Champ | Valeur |
# |---|---|
# | Système | PostgreSQL |
# | Serveur | `registre` |
# | Utilisateur | `auditeur` |
# | Mot de passe | `arche2152` |
# | Base | `arche` |
#
# ### Les 3 tables et leurs liens
# - **`habitants`** : `id`, `nom`, `station`
# - **`predictions`** : `prediction_id`, `habitant_id` → `habitants.id`, `score_survie`, `verdict`
# - **`logs`** : `log_id`, `prediction_id` → `predictions.prediction_id`, `action`, `auteur`, `horodatage`
#
# ### Ta démarche
# 1. Explore la table `logs`. Quelles `action` existent ?
# 2. Garde les actions de type modification manuelle (`MANUAL_OVERRIDE`).
# 3. **Joins** les 3 tables pour voir *qui* a été visé, *par qui*, et *à quelle heure*.
# 4. Un seul de ces overrides a eu lieu **en pleine nuit** (entre 02h00 et 03h00).
#    Son `log_id`, écrit sur 4 chiffres, est le fragment.

# %% [markdown]
# ## Option avancée : interroger depuis Python
# Si tu préfères, tu peux requêter la base ici (sinon, reste sur Adminer).

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://auditeur:arche2152@registre:5432/arche')

# Écris ta requête SQL entre les triples guillemets 👇
requete = """

"""
pd.read_sql(requete, engine)
