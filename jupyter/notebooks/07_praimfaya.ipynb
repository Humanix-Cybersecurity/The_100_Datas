# %% [markdown]
# # Acte VII (BONUS) · Praimfaya : le dernier abri
# **Compétence : fusion de données (`merge`) & filtres multiples**
#
# L'Abattage est suspendu… mais les réacteurs de l'Arche fondent. **Praimfaya**,
# la vague de radiation, balaie la Terre. Il reste **un seul site au sol** où
# l'humanité peut survivre. Les relevés sont éparpillés dans **trois fichiers** :
# à toi de les **croiser** pour trouver le bunker.
#
# **Jeux de données :**
# - `data/sites_abris.csv` — `site_id`, `nom`, `secteur`, `x`, `y`
# - `data/releves_radiation.csv` — `site_id`, `radiation_msv`
# - `data/releves_ressources.csv` — `site_id`, `eau_potable` (0/1), `capacite`, `indice_o2`
#
# ### Un site est survivable s'il remplit les **4 conditions** :
# 1. `radiation_msv` **< 100** (en-dessous, ce n'est pas létal)
# 2. `eau_potable` **== 1**
# 3. `capacite` **>= 50** (assez de place pour les survivants)
# 4. `indice_o2` **>= 19** (air respirable)
#
# ### Ta démarche
# 1. Charge les 3 fichiers.
# 2. **Fusionne**-les sur `site_id` (`pandas.merge`).
# 3. **Filtre** sur les 4 conditions à la fois : il ne doit rester **qu'un seul site**.
# 4. Lis son `secteur`.
# 5. *(Bonus)* trace une carte (`x`, `y`) de tous les sites et repère le bunker.
#
# 🎯 **Fragment :** `ARK{BUNKER_??}` (le `secteur` de l'unique abri, ex. `J7`).

# %%
import pandas as pd

# À toi de jouer 👇  (3 read_csv, puis merge sur 'site_id', puis filtre)

# %% [markdown]
# ### 🌍 Et après ?
# Trouver le bunker, c'était encore de l'analyse de données : croiser des sources,
# filtrer sur des critères clairs, vérifier qu'il ne reste qu'une réponse.
# C'est exactement le métier. *May we meet again.*
